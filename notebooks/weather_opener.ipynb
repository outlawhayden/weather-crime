# %%
import pandas as pd
import numpy as np
import pip
import os
from tqdm.notebook import tqdm, trange
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
try:
    __import__("xarray")
except ImportError:
    pip.main(['install', "xarray"])

import xarray as xr
pd.options.display.max_columns = None
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.transform import factor_cmap, factor_mark

# %%
# read in weather data
weather = pd.read_csv('../data/weather/NCEI_CDO.csv', low_memory = False)

# %%
weather.head()
# Out:
#        STATION                        NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 1  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 2  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 3  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 4  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
#
#          DATE  AWND AWND_ATTRIBUTES  DAPR DAPR_ATTRIBUTES  FMTM  \
# 0  2015-02-01   NaN             NaN   NaN             NaN   NaN
# 1  2015-02-02   NaN             NaN   NaN             NaN   NaN
# 2  2015-02-03   NaN             NaN   NaN             NaN   NaN
# 3  2015-02-04   NaN             NaN   NaN             NaN   NaN
# 4  2015-02-05   NaN             NaN   NaN             NaN   NaN
#
#   FMTM_ATTRIBUTES  MDPR MDPR_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  PRCP  \
# 0             NaN   NaN             NaN   NaN             NaN  0.03
# 1             NaN   NaN             NaN   NaN             NaN  0.04
# 2             NaN   NaN             NaN   NaN             NaN  0.00
# 3             NaN   NaN             NaN   NaN             NaN  0.50
# 4             NaN   NaN             NaN   NaN             NaN  0.59
#
#   PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG  \
# 0             ,,N   NaN             NaN   NaN             NaN   NaN
# 1             ,,N   NaN             NaN   NaN             NaN   NaN
# 2            T,,N   NaN             NaN   NaN             NaN   NaN
# 3             ,,N   NaN             NaN   NaN             NaN   NaN
# 4             ,,N   NaN             NaN   NaN             NaN   NaN
#
#   TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES  TOBS  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   TOBS_ATTRIBUTES  WDF2 WDF2_ATTRIBUTES  WDF5 WDF5_ATTRIBUTES  WSF2  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES  WT01 WT01_ATTRIBUTES  WT02  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WT02_ATTRIBUTES  WT03 WT03_ATTRIBUTES  WT04 WT04_ATTRIBUTES  WT05  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WT05_ATTRIBUTES  WT06 WT06_ATTRIBUTES  WT08 WT08_ATTRIBUTES  WT10  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WT10_ATTRIBUTES  WT11 WT11_ATTRIBUTES  WT13 WT13_ATTRIBUTES  WT14  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WT14_ATTRIBUTES  WT16 WT16_ATTRIBUTES  WT18 WT18_ATTRIBUTES  WT21  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WT21_ATTRIBUTES
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
station_list = weather["STATION"].unique()
station_list
# Out:
# array(['US1LAOR0006', 'US1LAOR0016', 'USW00012916', 'US1LAOR0003',
#        'US1LAOR0014', 'USC00166666', 'US1LAOR0012', 'USW00053917',
#        'USW00012930', 'US1LAOR0009', 'US1LAOR0019'], dtype=object)

# %%
weather.head(100)
# Out:
#         STATION                        NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0   US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 1   US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 2   US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 3   US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 4   US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# ..          ...                         ...        ...        ...        ...
# 95  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 96  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 97  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 98  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 99  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
#
#           DATE  AWND AWND_ATTRIBUTES  DAPR DAPR_ATTRIBUTES  FMTM  \
# 0   2015-02-01   NaN             NaN   NaN             NaN   NaN
# 1   2015-02-02   NaN             NaN   NaN             NaN   NaN
# 2   2015-02-03   NaN             NaN   NaN             NaN   NaN
# 3   2015-02-04   NaN             NaN   NaN             NaN   NaN
# 4   2015-02-05   NaN             NaN   NaN             NaN   NaN
# ..         ...   ...             ...   ...             ...   ...
# 95  2015-06-04   NaN             NaN   NaN             NaN   NaN
# 96  2015-06-05   NaN             NaN   NaN             NaN   NaN
# 97  2015-06-06   NaN             NaN   NaN             NaN   NaN
# 98  2015-06-07   NaN             NaN   NaN             NaN   NaN
# 99  2015-06-08   NaN             NaN   NaN             NaN   NaN
#
#    FMTM_ATTRIBUTES  MDPR MDPR_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  PRCP  \
# 0              NaN   NaN             NaN   NaN             NaN  0.03
# 1              NaN   NaN             NaN   NaN             NaN  0.04
# 2              NaN   NaN             NaN   NaN             NaN  0.00
# 3              NaN   NaN             NaN   NaN             NaN  0.50
# 4              NaN   NaN             NaN   NaN             NaN  0.59
# ..             ...   ...             ...   ...             ...   ...
# 95             NaN   NaN             NaN   NaN             NaN  0.00
# 96             NaN   NaN             NaN   NaN             NaN  0.00
# 97             NaN   NaN             NaN   NaN             NaN  0.00
# 98             NaN   NaN             NaN   NaN             NaN  0.00
# 99             NaN   NaN             NaN   NaN             NaN  0.00
#
#    PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG  \
# 0              ,,N   NaN             NaN   NaN             NaN   NaN
# 1              ,,N   NaN             NaN   NaN             NaN   NaN
# 2             T,,N   NaN             NaN   NaN             NaN   NaN
# 3              ,,N   NaN             NaN   NaN             NaN   NaN
# 4              ,,N   NaN             NaN   NaN             NaN   NaN
# ..             ...   ...             ...   ...             ...   ...
# 95             ,,N   0.0             ,,N   NaN             NaN   NaN
# 96             ,,N   0.0             ,,N   NaN             NaN   NaN
# 97             ,,N   0.0             ,,N   NaN             NaN   NaN
# 98             ,,N   0.0             ,,N   NaN             NaN   NaN
# 99             ,,N   0.0             ,,N   NaN             NaN   NaN
#
#    TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES  TOBS  \
# 0              NaN   NaN             NaN   NaN             NaN   NaN
# 1              NaN   NaN             NaN   NaN             NaN   NaN
# 2              NaN   NaN             NaN   NaN             NaN   NaN
# 3              NaN   NaN             NaN   NaN             NaN   NaN
# 4              NaN   NaN             NaN   NaN             NaN   NaN
# ..             ...   ...             ...   ...             ...   ...
# 95             NaN   NaN             NaN   NaN             NaN   NaN
# 96             NaN   NaN             NaN   NaN             NaN   NaN
# 97             NaN   NaN             NaN   NaN             NaN   NaN
# 98             NaN   NaN             NaN   NaN             NaN   NaN
# 99             NaN   NaN             NaN   NaN             NaN   NaN
#
#    TOBS_ATTRIBUTES  WDF2 WDF2_ATTRIBUTES  WDF5 WDF5_ATTRIBUTES  WSF2  \
# 0              NaN   NaN             NaN   NaN             NaN   NaN
# 1              NaN   NaN             NaN   NaN             NaN   NaN
# 2              NaN   NaN             NaN   NaN             NaN   NaN
# 3              NaN   NaN             NaN   NaN             NaN   NaN
# 4              NaN   NaN             NaN   NaN             NaN   NaN
# ..             ...   ...             ...   ...             ...   ...
# 95             NaN   NaN             NaN   NaN             NaN   NaN
# 96             NaN   NaN             NaN   NaN             NaN   NaN
# 97             NaN   NaN             NaN   NaN             NaN   NaN
# 98             NaN   NaN             NaN   NaN             NaN   NaN
# 99             NaN   NaN             NaN   NaN             NaN   NaN
#
#    WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES  WT01 WT01_ATTRIBUTES  WT02  \
# 0              NaN   NaN             NaN   NaN             NaN   NaN
# 1              NaN   NaN             NaN   NaN             NaN   NaN
# 2              NaN   NaN             NaN   NaN             NaN   NaN
# 3              NaN   NaN             NaN   NaN             NaN   NaN
# 4              NaN   NaN             NaN   NaN             NaN   NaN
# ..             ...   ...             ...   ...             ...   ...
# 95             NaN   NaN             NaN   NaN             NaN   NaN
# 96             NaN   NaN             NaN   NaN             NaN   NaN
# 97             NaN   NaN             NaN   NaN             NaN   NaN
# 98             NaN   NaN             NaN   NaN             NaN   NaN
# 99             NaN   NaN             NaN   NaN             NaN   NaN
#
#    WT02_ATTRIBUTES  WT03 WT03_ATTRIBUTES  WT04 WT04_ATTRIBUTES  WT05  \
# 0              NaN   NaN             NaN   NaN             NaN   NaN
# 1              NaN   NaN             NaN   NaN             NaN   NaN
# 2              NaN   NaN             NaN   NaN             NaN   NaN
# 3              NaN   NaN             NaN   NaN             NaN   NaN
# 4              NaN   NaN             NaN   NaN             NaN   NaN
# ..             ...   ...             ...   ...             ...   ...
# 95             NaN   NaN             NaN   NaN             NaN   NaN
# 96             NaN   NaN             NaN   NaN             NaN   NaN
# 97             NaN   NaN             NaN   NaN             NaN   NaN
# 98             NaN   NaN             NaN   NaN             NaN   NaN
# 99             NaN   NaN             NaN   NaN             NaN   NaN
#
#    WT05_ATTRIBUTES  WT06 WT06_ATTRIBUTES  WT08 WT08_ATTRIBUTES  WT10  \
# 0              NaN   NaN             NaN   NaN             NaN   NaN
# 1              NaN   NaN             NaN   NaN             NaN   NaN
# 2              NaN   NaN             NaN   NaN             NaN   NaN
# 3              NaN   NaN             NaN   NaN             NaN   NaN
# 4              NaN   NaN             NaN   NaN             NaN   NaN
# ..             ...   ...             ...   ...             ...   ...
# 95             NaN   NaN             NaN   NaN             NaN   NaN
# 96             NaN   NaN             NaN   NaN             NaN   NaN
# 97             NaN   NaN             NaN   NaN             NaN   NaN
# 98             NaN   NaN             NaN   NaN             NaN   NaN
# 99             NaN   NaN             NaN   NaN             NaN   NaN
#
#    WT10_ATTRIBUTES  WT11 WT11_ATTRIBUTES  WT13 WT13_ATTRIBUTES  WT14  \
# 0              NaN   NaN             NaN   NaN             NaN   NaN
# 1              NaN   NaN             NaN   NaN             NaN   NaN
# 2              NaN   NaN             NaN   NaN             NaN   NaN
# 3              NaN   NaN             NaN   NaN             NaN   NaN
# 4              NaN   NaN             NaN   NaN             NaN   NaN
# ..             ...   ...             ...   ...             ...   ...
# 95             NaN   NaN             NaN   NaN             NaN   NaN
# 96             NaN   NaN             NaN   NaN             NaN   NaN
# 97             NaN   NaN             NaN   NaN             NaN   NaN
# 98             NaN   NaN             NaN   NaN             NaN   NaN
# 99             NaN   NaN             NaN   NaN             NaN   NaN
#
#    WT14_ATTRIBUTES  WT16 WT16_ATTRIBUTES  WT18 WT18_ATTRIBUTES  WT21  \
# 0              NaN   NaN             NaN   NaN             NaN   NaN
# 1              NaN   NaN             NaN   NaN             NaN   NaN
# 2              NaN   NaN             NaN   NaN             NaN   NaN
# 3              NaN   NaN             NaN   NaN             NaN   NaN
# 4              NaN   NaN             NaN   NaN             NaN   NaN
# ..             ...   ...             ...   ...             ...   ...
# 95             NaN   NaN             NaN   NaN             NaN   NaN
# 96             NaN   NaN             NaN   NaN             NaN   NaN
# 97             NaN   NaN             NaN   NaN             NaN   NaN
# 98             NaN   NaN             NaN   NaN             NaN   NaN
# 99             NaN   NaN             NaN   NaN             NaN   NaN
#
#    WT21_ATTRIBUTES
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 95             NaN
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
#
# [100 rows x 66 columns]

# %%
weather.loc[weather["DATE"] == "2020-02-02"]
# Out:
#            STATION                                  NAME   LATITUDE  \
# 1419   US1LAOR0006            NEW ORLEANS 2.1 ENE, LA US  29.961679
# 6018   USW00012916            NEW ORLEANS AIRPORT, LA US  29.997550
# 8918   US1LAOR0003             NEW ORLEANS 3.6 SW, LA US  29.919548
# 11477  US1LAOR0012              NEW ORLEANS 4.8 N, LA US  30.019430
# 14866  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.049340
# 19123  USW00012930            NEW ORLEANS AUDUBON, LA US  29.916600
# 21082  US1LAOR0009              NEW ORLEANS 5.0 N, LA US  30.015150
#
#        LONGITUDE  ELEVATION        DATE  AWND AWND_ATTRIBUTES  DAPR  \
# 1419  -90.038803        2.4  2020-02-02   NaN             NaN   NaN
# 6018  -90.277720       -1.0  2020-02-02  6.49             ,,W   NaN
# 8918  -90.118474        3.0  2020-02-02   NaN             NaN   NaN
# 11477 -90.068660        0.0  2020-02-02   NaN             NaN   NaN
# 14866 -90.028990        0.9  2020-02-02  8.28             ,,W   NaN
# 19123 -90.130200        6.1  2020-02-02   NaN             NaN   NaN
# 21082 -90.065586        0.6  2020-02-02   NaN             NaN   NaN
#
#       DAPR_ATTRIBUTES  FMTM FMTM_ATTRIBUTES  MDPR MDPR_ATTRIBUTES  PGTM  \
# 1419              NaN   NaN             NaN   NaN             NaN   NaN
# 6018              NaN   NaN             NaN   NaN             NaN   NaN
# 8918              NaN   NaN             NaN   NaN             NaN   NaN
# 11477             NaN   NaN             NaN   NaN             NaN   NaN
# 14866             NaN   NaN             NaN   NaN             NaN   NaN
# 19123             NaN   NaN             NaN   NaN             NaN   NaN
# 21082             NaN   NaN             NaN   NaN             NaN   NaN
#
#       PGTM_ATTRIBUTES  PRCP PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES  SNWD  \
# 1419              NaN   0.0             ,,N   NaN             NaN   NaN
# 6018              NaN   0.0        ,,W,2400   NaN             NaN   NaN
# 8918              NaN   0.0             ,,N   0.0             ,,N   NaN
# 11477             NaN   0.0            T,,N   NaN             NaN   NaN
# 14866             NaN   0.0        ,,W,2400   NaN             NaN   NaN
# 19123             NaN   0.0            ,,7,   NaN             NaN   NaN
# 21082             NaN   0.0             ,,N   NaN             NaN   NaN
#
#       SNWD_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN  \
# 1419              NaN   NaN             NaN   NaN             NaN   NaN
# 6018              NaN  56.0            H,,S  74.0             ,,W  43.0
# 8918              NaN   NaN             NaN   NaN             NaN   NaN
# 11477             NaN   NaN             NaN   NaN             NaN   NaN
# 14866             NaN   NaN             NaN  69.0             ,,W  47.0
# 19123             NaN   NaN             NaN  60.0             ,,7  43.0
# 21082             NaN   NaN             NaN   NaN             NaN   NaN
#
#       TMIN_ATTRIBUTES  TOBS TOBS_ATTRIBUTES   WDF2 WDF2_ATTRIBUTES   WDF5  \
# 1419              NaN   NaN             NaN    NaN             NaN    NaN
# 6018              ,,W   NaN             NaN  250.0             ,,W  210.0
# 8918              NaN   NaN             NaN    NaN             NaN    NaN
# 11477             NaN   NaN             NaN    NaN             NaN    NaN
# 14866             ,,W   NaN             NaN  220.0             ,,W  220.0
# 19123             ,,7  43.0             ,,7    NaN             NaN    NaN
# 21082             NaN   NaN             NaN    NaN             NaN    NaN
#
#       WDF5_ATTRIBUTES  WSF2 WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES  WT01  \
# 1419              NaN   NaN             NaN   NaN             NaN   NaN
# 6018              ,,W  15.0             ,,W  21.0             ,,W   NaN
# 8918              NaN   NaN             NaN   NaN             NaN   NaN
# 11477             NaN   NaN             NaN   NaN             NaN   NaN
# 14866             ,,W  15.0             ,,W  18.1             ,,W   NaN
# 19123             NaN   NaN             NaN   NaN             NaN   NaN
# 21082             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT01_ATTRIBUTES  WT02 WT02_ATTRIBUTES  WT03 WT03_ATTRIBUTES  WT04  \
# 1419              NaN   NaN             NaN   NaN             NaN   NaN
# 6018              NaN   NaN             NaN   NaN             NaN   NaN
# 8918              NaN   NaN             NaN   NaN             NaN   NaN
# 11477             NaN   NaN             NaN   NaN             NaN   NaN
# 14866             NaN   NaN             NaN   NaN             NaN   NaN
# 19123             NaN   NaN             NaN   NaN             NaN   NaN
# 21082             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT04_ATTRIBUTES  WT05 WT05_ATTRIBUTES  WT06 WT06_ATTRIBUTES  WT08  \
# 1419              NaN   NaN             NaN   NaN             NaN   NaN
# 6018              NaN   NaN             NaN   NaN             NaN   NaN
# 8918              NaN   NaN             NaN   NaN             NaN   NaN
# 11477             NaN   NaN             NaN   NaN             NaN   NaN
# 14866             NaN   NaN             NaN   NaN             NaN   NaN
# 19123             NaN   NaN             NaN   NaN             NaN   NaN
# 21082             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT08_ATTRIBUTES  WT10 WT10_ATTRIBUTES  WT11 WT11_ATTRIBUTES  WT13  \
# 1419              NaN   NaN             NaN   NaN             NaN   NaN
# 6018              NaN   NaN             NaN   NaN             NaN   NaN
# 8918              NaN   NaN             NaN   NaN             NaN   NaN
# 11477             NaN   NaN             NaN   NaN             NaN   NaN
# 14866             NaN   NaN             NaN   NaN             NaN   NaN
# 19123             NaN   NaN             NaN   NaN             NaN   NaN
# 21082             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT13_ATTRIBUTES  WT14 WT14_ATTRIBUTES  WT16 WT16_ATTRIBUTES  WT18  \
# 1419              NaN   NaN             NaN   NaN             NaN   NaN
# 6018              NaN   NaN             NaN   NaN             NaN   NaN
# 8918              NaN   NaN             NaN   NaN             NaN   NaN
# 11477             NaN   NaN             NaN   NaN             NaN   NaN
# 14866             NaN   NaN             NaN   NaN             NaN   NaN
# 19123             NaN   NaN             NaN   NaN             NaN   NaN
# 21082             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT18_ATTRIBUTES  WT21 WT21_ATTRIBUTES
# 1419              NaN   NaN             NaN
# 6018              NaN   NaN             NaN
# 8918              NaN   NaN             NaN
# 11477             NaN   NaN             NaN
# 14866             NaN   NaN             NaN
# 19123             NaN   NaN             NaN
# 21082             NaN   NaN             NaN

# %%
weather.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'AWND_ATTRIBUTES', 'DAPR', 'DAPR_ATTRIBUTES', 'FMTM', 'FMTM_ATTRIBUTES',
#        'MDPR', 'MDPR_ATTRIBUTES', 'PGTM', 'PGTM_ATTRIBUTES', 'PRCP',
#        'PRCP_ATTRIBUTES', 'SNOW', 'SNOW_ATTRIBUTES', 'SNWD', 'SNWD_ATTRIBUTES',
#        'TAVG', 'TAVG_ATTRIBUTES', 'TMAX', 'TMAX_ATTRIBUTES', 'TMIN',
#        'TMIN_ATTRIBUTES', 'TOBS', 'TOBS_ATTRIBUTES', 'WDF2', 'WDF2_ATTRIBUTES',
#        'WDF5', 'WDF5_ATTRIBUTES', 'WSF2', 'WSF2_ATTRIBUTES', 'WSF5',
#        'WSF5_ATTRIBUTES', 'WT01', 'WT01_ATTRIBUTES', 'WT02', 'WT02_ATTRIBUTES',
#        'WT03', 'WT03_ATTRIBUTES', 'WT04', 'WT04_ATTRIBUTES', 'WT05',
#        'WT05_ATTRIBUTES', 'WT06', 'WT06_ATTRIBUTES', 'WT08', 'WT08_ATTRIBUTES',
#        'WT10', 'WT10_ATTRIBUTES', 'WT11', 'WT11_ATTRIBUTES', 'WT13',
#        'WT13_ATTRIBUTES', 'WT14', 'WT14_ATTRIBUTES', 'WT16', 'WT16_ATTRIBUTES',
#        'WT18', 'WT18_ATTRIBUTES', 'WT21', 'WT21_ATTRIBUTES'],
#       dtype='object')

# %%
end_columns = ['WT01', 'WT01_ATTRIBUTES', 'WT02', 'WT02_ATTRIBUTES',
       'WT03', 'WT03_ATTRIBUTES', 'WT04', 'WT04_ATTRIBUTES', 'WT05',
       'WT05_ATTRIBUTES', 'WT06', 'WT06_ATTRIBUTES', 'WT08', 'WT08_ATTRIBUTES',
       'WT10', 'WT10_ATTRIBUTES', 'WT11', 'WT11_ATTRIBUTES', 'WT13',
       'WT13_ATTRIBUTES', 'WT14', 'WT14_ATTRIBUTES', 'WT16', 'WT16_ATTRIBUTES',
       'WT18', 'WT18_ATTRIBUTES', 'WT21', 'WT21_ATTRIBUTES']

weather[end_columns]
# Out:
#        WT01 WT01_ATTRIBUTES  WT02 WT02_ATTRIBUTES  WT03 WT03_ATTRIBUTES  WT04  \
# 0       NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 1       NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 2       NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 3       NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 4       NaN             NaN   NaN             NaN   NaN             NaN   NaN
# ...     ...             ...   ...             ...   ...             ...   ...
# 23474   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 23475   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 23476   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 23477   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 23478   NaN             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT04_ATTRIBUTES  WT05 WT05_ATTRIBUTES  WT06 WT06_ATTRIBUTES  WT08  \
# 0                 NaN   NaN             NaN   NaN             NaN   NaN
# 1                 NaN   NaN             NaN   NaN             NaN   NaN
# 2                 NaN   NaN             NaN   NaN             NaN   NaN
# 3                 NaN   NaN             NaN   NaN             NaN   NaN
# 4                 NaN   NaN             NaN   NaN             NaN   NaN
# ...               ...   ...             ...   ...             ...   ...
# 23474             NaN   NaN             NaN   NaN             NaN   NaN
# 23475             NaN   NaN             NaN   NaN             NaN   NaN
# 23476             NaN   NaN             NaN   NaN             NaN   NaN
# 23477             NaN   NaN             NaN   NaN             NaN   NaN
# 23478             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT08_ATTRIBUTES  WT10 WT10_ATTRIBUTES  WT11 WT11_ATTRIBUTES  WT13  \
# 0                 NaN   NaN             NaN   NaN             NaN   NaN
# 1                 NaN   NaN             NaN   NaN             NaN   NaN
# 2                 NaN   NaN             NaN   NaN             NaN   NaN
# 3                 NaN   NaN             NaN   NaN             NaN   NaN
# 4                 NaN   NaN             NaN   NaN             NaN   NaN
# ...               ...   ...             ...   ...             ...   ...
# 23474             NaN   NaN             NaN   NaN             NaN   NaN
# 23475             NaN   NaN             NaN   NaN             NaN   NaN
# 23476             NaN   NaN             NaN   NaN             NaN   NaN
# 23477             NaN   NaN             NaN   NaN             NaN   NaN
# 23478             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT13_ATTRIBUTES  WT14 WT14_ATTRIBUTES  WT16 WT16_ATTRIBUTES  WT18  \
# 0                 NaN   NaN             NaN   NaN             NaN   NaN
# 1                 NaN   NaN             NaN   NaN             NaN   NaN
# 2                 NaN   NaN             NaN   NaN             NaN   NaN
# 3                 NaN   NaN             NaN   NaN             NaN   NaN
# 4                 NaN   NaN             NaN   NaN             NaN   NaN
# ...               ...   ...             ...   ...             ...   ...
# 23474             NaN   NaN             NaN   NaN             NaN   NaN
# 23475             NaN   NaN             NaN   NaN             NaN   NaN
# 23476             NaN   NaN             NaN   NaN             NaN   NaN
# 23477             NaN   NaN             NaN   NaN             NaN   NaN
# 23478             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT18_ATTRIBUTES  WT21 WT21_ATTRIBUTES
# 0                 NaN   NaN             NaN
# 1                 NaN   NaN             NaN
# 2                 NaN   NaN             NaN
# 3                 NaN   NaN             NaN
# 4                 NaN   NaN             NaN
# ...               ...   ...             ...
# 23474             NaN   NaN             NaN
# 23475             NaN   NaN             NaN
# 23476             NaN   NaN             NaN
# 23477             NaN   NaN             NaN
# 23478             NaN   NaN             NaN
#
# [23479 rows x 28 columns]

# %%
for c, column in enumerate(end_columns):
    percent_missing = weather[column].isnull().sum() * 100 / len(weather[column])
    print("Column %s missing %f of data" %(column, percent_missing))
# Out:
# Column WT01 missing 89.130713 of data
# Column WT01_ATTRIBUTES missing 89.130713 of data
# Column WT02 missing 98.411346 of data
# Column WT02_ATTRIBUTES missing 98.411346 of data
# Column WT03 missing 93.462243 of data
# Column WT03_ATTRIBUTES missing 93.462243 of data
# Column WT04 missing 99.970186 of data
# Column WT04_ATTRIBUTES missing 99.970186 of data
# Column WT05 missing 99.953150 of data
# Column WT05_ATTRIBUTES missing 99.953150 of data
# Column WT06 missing 99.991482 of data
# Column WT06_ATTRIBUTES missing 99.991482 of data
# Column WT08 missing 95.025342 of data
# Column WT08_ATTRIBUTES missing 95.025342 of data
# Column WT10 missing 99.936113 of data
# Column WT10_ATTRIBUTES missing 99.936113 of data
# Column WT11 missing 99.987223 of data
# Column WT11_ATTRIBUTES missing 99.987223 of data
# Column WT13 missing 98.781890 of data
# Column WT13_ATTRIBUTES missing 98.781890 of data
# Column WT14 missing 99.825376 of data
# Column WT14_ATTRIBUTES missing 99.825376 of data
# Column WT16 missing 98.735040 of data
# Column WT16_ATTRIBUTES missing 98.735040 of data
# Column WT18 missing 99.995741 of data
# Column WT18_ATTRIBUTES missing 99.995741 of data
# Column WT21 missing 99.659270 of data
# Column WT21_ATTRIBUTES missing 99.659270 of data

# %%
weather[weather["WT02"].notnull()]
# Out:
#            STATION                                  NAME  LATITUDE  LONGITUDE  \
# 2716   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# 2729   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# 2745   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# 2747   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# 2748   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# ...            ...                                   ...       ...        ...
# 15962  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
# 15990  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
# 16028  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
# 16164  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
# 16170  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
#
#        ELEVATION        DATE   AWND AWND_ATTRIBUTES  DAPR DAPR_ATTRIBUTES  \
# 2716        -1.0  2011-01-18   6.93             ,,W   NaN             NaN
# 2729        -1.0  2011-01-31   5.37             ,,W   NaN             NaN
# 2745        -1.0  2011-02-16   3.80             ,,W   NaN             NaN
# 2747        -1.0  2011-02-18   5.14             ,,W   NaN             NaN
# 2748        -1.0  2011-02-19   3.80             ,,W   NaN             NaN
# ...          ...         ...    ...             ...   ...             ...
# 15962        0.9  2023-02-08  15.66             ,,W   NaN             NaN
# 15990        0.9  2023-03-08   6.49             ,,W   NaN             NaN
# 16028        0.9  2023-04-15   9.62             ,,W   NaN             NaN
# 16164        0.9  2023-08-29  12.30             ,,W   NaN             NaN
# 16170        0.9  2023-09-04   6.26             ,,W   NaN             NaN
#
#          FMTM FMTM_ATTRIBUTES  MDPR MDPR_ATTRIBUTES    PGTM PGTM_ATTRIBUTES  \
# 2716   1733.0             ,,X   NaN             NaN  1732.0             ,,W
# 2729   2245.0             ,,X   NaN             NaN  2253.0             ,,W
# 2745   1708.0             ,,X   NaN             NaN  1641.0             ,,W
# 2747   1541.0             ,,X   NaN             NaN  1409.0             ,,W
# 2748   1247.0             ,,X   NaN             NaN     NaN             NaN
# ...       ...             ...   ...             ...     ...             ...
# 15962     NaN             NaN   NaN             NaN     NaN             NaN
# 15990     NaN             NaN   NaN             NaN     NaN             NaN
# 16028     NaN             NaN   NaN             NaN     NaN             NaN
# 16164     NaN             NaN   NaN             NaN     NaN             NaN
# 16170     NaN             NaN   NaN             NaN     NaN             NaN
#
#        PRCP PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG  \
# 2716   0.95        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# 2729   0.00        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# 2745   0.00        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# 2747   0.00        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# 2748   0.00        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# ...     ...             ...   ...             ...   ...             ...   ...
# 15962  1.32        ,,W,2400   0.0             ,,D   NaN             NaN   NaN
# 15990  0.00        ,,W,2400   NaN             NaN   NaN             NaN   NaN
# 16028  0.75        ,,W,2400   NaN             NaN   NaN             NaN   NaN
# 16164  1.85        ,,W,2400   NaN             NaN   NaN             NaN   NaN
# 16170  2.71        ,,W,2400   0.0             ,,W   NaN             NaN   NaN
#
#       TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES  TOBS  \
# 2716              NaN  73.0             ,,X  45.0             ,,X   NaN
# 2729              NaN  68.0             ,,X  54.0             ,,X   NaN
# 2745              NaN  69.0             ,,X  47.0             ,,X   NaN
# 2747              NaN  80.0             ,,X  58.0             ,,X   NaN
# 2748              NaN  76.0             ,,X  57.0             ,,X   NaN
# ...               ...   ...             ...   ...             ...   ...
# 15962             NaN  80.0             ,,W  65.0             ,,W   NaN
# 15990             NaN  79.0             ,,W  70.0             ,,W   NaN
# 16028             NaN  81.0             ,,W  65.0             ,,W   NaN
# 16164             NaN  94.0             ,,W  76.0             ,,W   NaN
# 16170             NaN  87.0             ,,W  77.0             ,,W   NaN
#
#       TOBS_ATTRIBUTES   WDF2 WDF2_ATTRIBUTES   WDF5 WDF5_ATTRIBUTES  WSF2  \
# 2716              NaN  290.0             ,,X  290.0             ,,X  29.1
# 2729              NaN  140.0             ,,X  130.0             ,,X  13.0
# 2745              NaN  170.0             ,,X  180.0             ,,X  13.0
# 2747              NaN   50.0             ,,X  160.0             ,,X  12.1
# 2748              NaN   10.0             ,,X    NaN             NaN  12.1
# ...               ...    ...             ...    ...             ...   ...
# 15962             NaN  250.0             ,,W  240.0             ,,W  42.9
# 15990             NaN  330.0             ,,W  320.0             ,,W  10.1
# 16028             NaN  320.0             ,,W  320.0             ,,W  44.1
# 16164             NaN   30.0             ,,W  340.0             ,,W  23.0
# 16170             NaN   30.0             ,,W   20.0             ,,W  25.1
#
#       WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES  WT01 WT01_ATTRIBUTES  WT02  \
# 2716              ,,X  38.9             ,,X   1.0             ,,W   1.0
# 2729              ,,X  16.1             ,,X   1.0             ,,W   1.0
# 2745              ,,X  16.1             ,,X   1.0             ,,W   1.0
# 2747              ,,X  23.0             ,,X   1.0             ,,W   1.0
# 2748              ,,X   NaN             NaN   1.0             ,,W   1.0
# ...               ...   ...             ...   ...             ...   ...
# 15962             ,,W  53.0             ,,W   1.0             ,,W   1.0
# 15990             ,,W  13.0             ,,W   1.0             ,,W   1.0
# 16028             ,,W  59.1             ,,W   1.0             ,,W   1.0
# 16164             ,,W  29.1             ,,W   1.0             ,,W   1.0
# 16170             ,,W  31.1             ,,W   1.0             ,,W   1.0
#
#       WT02_ATTRIBUTES  WT03 WT03_ATTRIBUTES  WT04 WT04_ATTRIBUTES  WT05  \
# 2716              ,,W   1.0             ,,X   NaN             NaN   NaN
# 2729              ,,W   NaN             NaN   NaN             NaN   NaN
# 2745              ,,W   NaN             NaN   NaN             NaN   NaN
# 2747              ,,W   NaN             NaN   NaN             NaN   NaN
# 2748              ,,W   NaN             NaN   NaN             NaN   NaN
# ...               ...   ...             ...   ...             ...   ...
# 15962             ,,W   1.0             ,,W   NaN             NaN   NaN
# 15990             ,,W   NaN             NaN   NaN             NaN   NaN
# 16028             ,,W   1.0             ,,W   NaN             NaN   NaN
# 16164             ,,W   1.0             ,,W   NaN             NaN   NaN
# 16170             ,,W   1.0             ,,W   NaN             NaN   NaN
#
#       WT05_ATTRIBUTES  WT06 WT06_ATTRIBUTES  WT08 WT08_ATTRIBUTES  WT10  \
# 2716              NaN   NaN             NaN   1.0             ,,X   NaN
# 2729              NaN   NaN             NaN   1.0             ,,X   NaN
# 2745              NaN   NaN             NaN   1.0             ,,X   NaN
# 2747              NaN   NaN             NaN   1.0             ,,X   NaN
# 2748              NaN   NaN             NaN   1.0             ,,X   NaN
# ...               ...   ...             ...   ...             ...   ...
# 15962             NaN   NaN             NaN   NaN             NaN   NaN
# 15990             NaN   NaN             NaN   1.0             ,,W   NaN
# 16028             NaN   NaN             NaN   NaN             NaN   NaN
# 16164             NaN   NaN             NaN   NaN             NaN   NaN
# 16170             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT10_ATTRIBUTES  WT11 WT11_ATTRIBUTES  WT13 WT13_ATTRIBUTES  WT14  \
# 2716              NaN   NaN             NaN   NaN             NaN   NaN
# 2729              NaN   NaN             NaN   1.0             ,,X   NaN
# 2745              NaN   NaN             NaN   1.0             ,,X   NaN
# 2747              NaN   NaN             NaN   1.0             ,,X   NaN
# 2748              NaN   NaN             NaN   1.0             ,,X   NaN
# ...               ...   ...             ...   ...             ...   ...
# 15962             NaN   NaN             NaN   NaN             NaN   NaN
# 15990             NaN   NaN             NaN   NaN             NaN   NaN
# 16028             NaN   NaN             NaN   NaN             NaN   NaN
# 16164             NaN   NaN             NaN   NaN             NaN   NaN
# 16170             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT14_ATTRIBUTES  WT16 WT16_ATTRIBUTES  WT18 WT18_ATTRIBUTES  WT21  \
# 2716              NaN   1.0             ,,X   NaN             NaN   NaN
# 2729              NaN   NaN             NaN   NaN             NaN   NaN
# 2745              NaN   NaN             NaN   NaN             NaN   1.0
# 2747              NaN   NaN             NaN   NaN             NaN   NaN
# 2748              NaN   NaN             NaN   NaN             NaN   NaN
# ...               ...   ...             ...   ...             ...   ...
# 15962             NaN   NaN             NaN   NaN             NaN   NaN
# 15990             NaN   NaN             NaN   NaN             NaN   NaN
# 16028             NaN   NaN             NaN   NaN             NaN   NaN
# 16164             NaN   NaN             NaN   NaN             NaN   NaN
# 16170             NaN   NaN             NaN   NaN             NaN   NaN
#
#       WT21_ATTRIBUTES
# 2716              NaN
# 2729              NaN
# 2745              ,,X
# 2747              NaN
# 2748              NaN
# ...               ...
# 15962             NaN
# 15990             NaN
# 16028             NaN
# 16164             NaN
# 16170             NaN
#
# [373 rows x 66 columns]

# %%
special_attribute_labels = {"WT01":"Fog","WT02":"Heavy Fog","WT03":"Thunder","WT04":"Ice Pellets", "WT05":"Hail", "WT06":"Rime", 
                            "WT07": "Dust", "WT08":"Smoke", "WT09":"Blowing Snow", "WT10":"Tornado", "WT11":"High Wind", "WT12":"Blowing Spray",
                            "WT13":"Mist", "WT14":"Drizzle", "WT15":"Freezing Drizzle", "WT16":"Rain", "WT17":"Freezing Rain", "WT18":"Snow", "WT19":"Unknown Precipitation",
                           "WT21":"Ground Fog", "WT22":"Ice Fog"}

# %%
for col in special_attribute_labels:
    if col in weather.columns:
        weather[col] = weather[col].notnull()
    attribute = col + "_ATTRIBUTES"
    if attribute in weather.columns:
        weather.drop(attribute, inplace = True, axis = 1)

weather.rename(columns = special_attribute_labels, inplace = True)

# %%
weather.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'AWND_ATTRIBUTES', 'DAPR', 'DAPR_ATTRIBUTES', 'FMTM', 'FMTM_ATTRIBUTES',
#        'MDPR', 'MDPR_ATTRIBUTES', 'PGTM', 'PGTM_ATTRIBUTES', 'PRCP',
#        'PRCP_ATTRIBUTES', 'SNOW', 'SNOW_ATTRIBUTES', 'SNWD', 'SNWD_ATTRIBUTES',
#        'TAVG', 'TAVG_ATTRIBUTES', 'TMAX', 'TMAX_ATTRIBUTES', 'TMIN',
#        'TMIN_ATTRIBUTES', 'TOBS', 'TOBS_ATTRIBUTES', 'WDF2', 'WDF2_ATTRIBUTES',
#        'WDF5', 'WDF5_ATTRIBUTES', 'WSF2', 'WSF2_ATTRIBUTES', 'WSF5',
#        'WSF5_ATTRIBUTES', 'Fog', 'Heavy Fog', 'Thunder', 'Ice Pellets', 'Hail',
#        'Rime', 'Smoke', 'Tornado', 'High Wind', 'Mist', 'Drizzle', 'Rain',
#        'Snow', 'Ground Fog'],
#       dtype='object')

# %%
weather.iloc[[2716]]
# Out:
#           STATION                        NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 2716  USW00012916  NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772       -1.0
#
#             DATE  AWND AWND_ATTRIBUTES  DAPR DAPR_ATTRIBUTES    FMTM  \
# 2716  2011-01-18  6.93             ,,W   NaN             NaN  1733.0
#
#      FMTM_ATTRIBUTES  MDPR MDPR_ATTRIBUTES    PGTM PGTM_ATTRIBUTES  PRCP  \
# 2716             ,,X   NaN             NaN  1732.0             ,,W  0.95
#
#      PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG  \
# 2716        ,,X,2400   NaN             NaN   NaN             NaN   NaN
#
#      TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES  TOBS  \
# 2716             NaN  73.0             ,,X  45.0             ,,X   NaN
#
#      TOBS_ATTRIBUTES   WDF2 WDF2_ATTRIBUTES   WDF5 WDF5_ATTRIBUTES  WSF2  \
# 2716             NaN  290.0             ,,X  290.0             ,,X  29.1
#
#      WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES   Fog  Heavy Fog  Thunder  \
# 2716             ,,X  38.9             ,,X  True       True     True
#
#       Ice Pellets   Hail   Rime  Smoke  Tornado  High Wind   Mist  Drizzle  \
# 2716        False  False  False   True    False      False  False    False
#
#       Rain   Snow  Ground Fog
# 2716  True  False       False

# %%
weather.head()
# Out:
#        STATION                        NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 1  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 2  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 3  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 4  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
#
#          DATE  AWND AWND_ATTRIBUTES  DAPR DAPR_ATTRIBUTES  FMTM  \
# 0  2015-02-01   NaN             NaN   NaN             NaN   NaN
# 1  2015-02-02   NaN             NaN   NaN             NaN   NaN
# 2  2015-02-03   NaN             NaN   NaN             NaN   NaN
# 3  2015-02-04   NaN             NaN   NaN             NaN   NaN
# 4  2015-02-05   NaN             NaN   NaN             NaN   NaN
#
#   FMTM_ATTRIBUTES  MDPR MDPR_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  PRCP  \
# 0             NaN   NaN             NaN   NaN             NaN  0.03
# 1             NaN   NaN             NaN   NaN             NaN  0.04
# 2             NaN   NaN             NaN   NaN             NaN  0.00
# 3             NaN   NaN             NaN   NaN             NaN  0.50
# 4             NaN   NaN             NaN   NaN             NaN  0.59
#
#   PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG  \
# 0             ,,N   NaN             NaN   NaN             NaN   NaN
# 1             ,,N   NaN             NaN   NaN             NaN   NaN
# 2            T,,N   NaN             NaN   NaN             NaN   NaN
# 3             ,,N   NaN             NaN   NaN             NaN   NaN
# 4             ,,N   NaN             NaN   NaN             NaN   NaN
#
#   TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES  TOBS  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   TOBS_ATTRIBUTES  WDF2 WDF2_ATTRIBUTES  WDF5 WDF5_ATTRIBUTES  WSF2  \
# 0             NaN   NaN             NaN   NaN             NaN   NaN
# 1             NaN   NaN             NaN   NaN             NaN   NaN
# 2             NaN   NaN             NaN   NaN             NaN   NaN
# 3             NaN   NaN             NaN   NaN             NaN   NaN
# 4             NaN   NaN             NaN   NaN             NaN   NaN
#
#   WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES    Fog  Heavy Fog  Thunder  \
# 0             NaN   NaN             NaN  False      False    False
# 1             NaN   NaN             NaN  False      False    False
# 2             NaN   NaN             NaN  False      False    False
# 3             NaN   NaN             NaN  False      False    False
# 4             NaN   NaN             NaN  False      False    False
#
#    Ice Pellets   Hail   Rime  Smoke  Tornado  High Wind   Mist  Drizzle  \
# 0        False  False  False  False    False      False  False    False
# 1        False  False  False  False    False      False  False    False
# 2        False  False  False  False    False      False  False    False
# 3        False  False  False  False    False      False  False    False
# 4        False  False  False  False    False      False  False    False
#
#     Rain   Snow  Ground Fog
# 0  False  False       False
# 1  False  False       False
# 2  False  False       False
# 3  False  False       False
# 4  False  False       False

# %%
weather["DATE"] = pd.to_datetime(weather["DATE"])

# %%
weather[weather["AWND"].notnull()]
# Out:
#            STATION                                  NAME  LATITUDE  LONGITUDE  \
# 2699   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# 2700   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# 2701   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# 2702   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# 2703   USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755  -90.27772
# ...            ...                                   ...       ...        ...
# 16190  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
# 16191  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
# 16192  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
# 16193  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
# 16194  USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934  -90.02899
#
#        ELEVATION       DATE   AWND AWND_ATTRIBUTES  DAPR DAPR_ATTRIBUTES  \
# 2699        -1.0 2011-01-01  12.75             ,,W   NaN             NaN
# 2700        -1.0 2011-01-02  13.42             ,,W   NaN             NaN
# 2701        -1.0 2011-01-03   6.71             ,,W   NaN             NaN
# 2702        -1.0 2011-01-04   3.80             ,,W   NaN             NaN
# 2703        -1.0 2011-01-05   7.16             ,,W   NaN             NaN
# ...          ...        ...    ...             ...   ...             ...
# 16190        0.9 2023-09-24   6.04             ,,W   NaN             NaN
# 16191        0.9 2023-09-25   5.14             ,,W   NaN             NaN
# 16192        0.9 2023-09-26   6.26             ,,W   NaN             NaN
# 16193        0.9 2023-09-27  11.41             ,,W   NaN             NaN
# 16194        0.9 2023-09-28  15.43             ,,W   NaN             NaN
#
#          FMTM FMTM_ATTRIBUTES  MDPR MDPR_ATTRIBUTES    PGTM PGTM_ATTRIBUTES  \
# 2699   1013.0             ,,X   NaN             NaN  1003.0             ,,W
# 2700    850.0             ,,X   NaN             NaN   843.0             ,,W
# 2701    127.0             ,,X   NaN             NaN   854.0             ,,W
# 2702   1652.0             ,,X   NaN             NaN   845.0             ,,W
# 2703   1140.0             ,,X   NaN             NaN   638.0             ,,W
# ...       ...             ...   ...             ...     ...             ...
# 16190     NaN             NaN   NaN             NaN     NaN             NaN
# 16191     NaN             NaN   NaN             NaN     NaN             NaN
# 16192     NaN             NaN   NaN             NaN     NaN             NaN
# 16193     NaN             NaN   NaN             NaN     NaN             NaN
# 16194     NaN             NaN   NaN             NaN  1815.0             ,,W
#
#        PRCP PRCP_ATTRIBUTES  SNOW SNOW_ATTRIBUTES  SNWD SNWD_ATTRIBUTES  TAVG  \
# 2699   0.18        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# 2700   0.00        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# 2701   0.00        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# 2702   0.02        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# 2703   0.90        ,,X,2400   NaN             NaN   NaN             NaN   NaN
# ...     ...             ...   ...             ...   ...             ...   ...
# 16190  0.00        ,,W,2400   NaN             NaN   NaN             NaN   NaN
# 16191  0.18        ,,W,2400   NaN             NaN   NaN             NaN   NaN
# 16192  0.00        ,,W,2400   NaN             NaN   NaN             NaN   NaN
# 16193  0.00        ,,W,2400   NaN             NaN   NaN             NaN   NaN
# 16194  0.00        ,,W,2400   NaN             NaN   NaN             NaN   NaN
#
#       TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN TMIN_ATTRIBUTES  TOBS  \
# 2699              NaN  73.0             ,,X  50.0             ,,X   NaN
# 2700              NaN  55.0             ,,X  42.0             ,,X   NaN
# 2701              NaN  56.0             ,,X  39.0             ,,X   NaN
# 2702              NaN  69.0             ,,X  50.0             ,,X   NaN
# 2703              NaN  70.0             ,,X  57.0             ,,X   NaN
# ...               ...   ...             ...   ...             ...   ...
# 16190             NaN  92.0             ,,W  78.0             ,,W   NaN
# 16191             NaN  91.0             ,,W  78.0             ,,W   NaN
# 16192             NaN  90.0             ,,W  79.0             ,,W   NaN
# 16193             NaN  91.0             ,,W  80.0             ,,W   NaN
# 16194             NaN  87.0             ,,W  77.0             ,,W   NaN
#
#       TOBS_ATTRIBUTES   WDF2 WDF2_ATTRIBUTES   WDF5 WDF5_ATTRIBUTES  WSF2  \
# 2699              NaN  340.0             ,,X  320.0             ,,X  21.0
# 2700              NaN   20.0             ,,X   20.0             ,,X  19.9
# 2701              NaN   50.0             ,,X   70.0             ,,X  16.1
# 2702              NaN  180.0             ,,X   40.0             ,,X   8.9
# 2703              NaN  240.0             ,,X  310.0             ,,X  16.1
# ...               ...    ...             ...    ...             ...   ...
# 16190             NaN  180.0             ,,W  220.0             ,,W  15.0
# 16191             NaN  250.0             ,,W  260.0             ,,W  15.0
# 16192             NaN  330.0             ,,W  330.0             ,,W  12.1
# 16193             NaN   60.0             ,,W   60.0             ,,W  21.0
# 16194             NaN   60.0             ,,W   90.0             ,,W  21.9
#
#       WSF2_ATTRIBUTES  WSF5 WSF5_ATTRIBUTES    Fog  Heavy Fog  Thunder  \
# 2699              ,,X  30.0             ,,X   True      False    False
# 2700              ,,X  23.9             ,,X  False      False    False
# 2701              ,,X  21.0             ,,X  False      False    False
# 2702              ,,X  13.0             ,,X   True      False    False
# 2703              ,,X  21.9             ,,X   True      False    False
# ...               ...   ...             ...    ...        ...      ...
# 16190             ,,W  19.9             ,,W  False      False     True
# 16191             ,,W  17.0             ,,W  False      False     True
# 16192             ,,W  15.0             ,,W  False      False    False
# 16193             ,,W  23.9             ,,W  False      False    False
# 16194             ,,W  25.9             ,,W  False      False    False
#
#        Ice Pellets   Hail   Rime  Smoke  Tornado  High Wind   Mist  Drizzle  \
# 2699         False  False  False  False    False      False   True     True
# 2700         False  False  False  False    False      False  False    False
# 2701         False  False  False  False    False      False  False    False
# 2702         False  False  False   True    False      False   True    False
# 2703         False  False  False  False    False      False   True    False
# ...            ...    ...    ...    ...      ...        ...    ...      ...
# 16190        False  False  False  False    False      False  False    False
# 16191        False  False  False  False    False      False  False    False
# 16192        False  False  False  False    False      False  False    False
# 16193        False  False  False  False    False      False  False    False
# 16194        False  False  False  False    False      False  False    False
#
#         Rain   Snow  Ground Fog
# 2699    True  False       False
# 2700   False  False       False
# 2701   False  False       False
# 2702    True  False       False
# 2703    True  False       False
# ...      ...    ...         ...
# 16190  False  False       False
# 16191  False  False       False
# 16192  False  False       False
# 16193  False  False       False
# 16194  False  False       False
#
# [8616 rows x 52 columns]

# %%
weather.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'AWND_ATTRIBUTES', 'DAPR', 'DAPR_ATTRIBUTES', 'FMTM', 'FMTM_ATTRIBUTES',
#        'MDPR', 'MDPR_ATTRIBUTES', 'PGTM', 'PGTM_ATTRIBUTES', 'PRCP',
#        'PRCP_ATTRIBUTES', 'SNOW', 'SNOW_ATTRIBUTES', 'SNWD', 'SNWD_ATTRIBUTES',
#        'TAVG', 'TAVG_ATTRIBUTES', 'TMAX', 'TMAX_ATTRIBUTES', 'TMIN',
#        'TMIN_ATTRIBUTES', 'TOBS', 'TOBS_ATTRIBUTES', 'WDF2', 'WDF2_ATTRIBUTES',
#        'WDF5', 'WDF5_ATTRIBUTES', 'WSF2', 'WSF2_ATTRIBUTES', 'WSF5',
#        'WSF5_ATTRIBUTES', 'Fog', 'Heavy Fog', 'Thunder', 'Ice Pellets', 'Hail',
#        'Rime', 'Smoke', 'Tornado', 'High Wind', 'Mist', 'Drizzle', 'Rain',
#        'Snow', 'Ground Fog'],
#       dtype='object')

# %%
general_attribute_labels = {"AWND":"AverageDailyWind", "DAPR":"NumDaysPrecipAvg", "FMTM":"FastestWindTime",
                      "MDPR":"MultidayPrecipTotal", "PGTM":"PeakGustTime", "PRCP":"Precipitation", "SNOW":"Snowfall",
                      "SNWD":"MinSoilTemp", "TAVG":"TimeAvgTemp", "TMAX":"TimeMaxTemp", "TMIN":"TimeMinTemp","TOBS":"TempAtObs", "WDF2":"2MinMaxWindDirection",
                      "WDF5":"5MinMaxWindDirection", "WSF2":"2MinMaxWindSpeed", "WSF5":"5MinMaxWindSpeed"}

# %%
weather.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'AWND_ATTRIBUTES', 'DAPR', 'DAPR_ATTRIBUTES', 'FMTM', 'FMTM_ATTRIBUTES',
#        'MDPR', 'MDPR_ATTRIBUTES', 'PGTM', 'PGTM_ATTRIBUTES', 'PRCP',
#        'PRCP_ATTRIBUTES', 'SNOW', 'SNOW_ATTRIBUTES', 'SNWD', 'SNWD_ATTRIBUTES',
#        'TAVG', 'TAVG_ATTRIBUTES', 'TMAX', 'TMAX_ATTRIBUTES', 'TMIN',
#        'TMIN_ATTRIBUTES', 'TOBS', 'TOBS_ATTRIBUTES', 'WDF2', 'WDF2_ATTRIBUTES',
#        'WDF5', 'WDF5_ATTRIBUTES', 'WSF2', 'WSF2_ATTRIBUTES', 'WSF5',
#        'WSF5_ATTRIBUTES', 'Fog', 'Heavy Fog', 'Thunder', 'Ice Pellets', 'Hail',
#        'Rime', 'Smoke', 'Tornado', 'High Wind', 'Mist', 'Drizzle', 'Rain',
#        'Snow', 'Ground Fog'],
#       dtype='object')

# %%
for c, col in enumerate(general_attribute_labels):
    attribute = col + "_ATTRIBUTES"
    if attribute in weather.columns:
        weather.drop(attribute, inplace = True, axis = 1)
        
weather.rename(columns = general_attribute_labels, inplace = True)

# %%
weather.head()
# Out:
#        STATION                        NAME   LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 1  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 2  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 3  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
# 4  US1LAOR0006  NEW ORLEANS 2.1 ENE, LA US  29.961679 -90.038803        2.4
#
#         DATE  AverageDailyWind  NumDaysPrecipAvg  FastestWindTime  \
# 0 2015-02-01               NaN               NaN              NaN
# 1 2015-02-02               NaN               NaN              NaN
# 2 2015-02-03               NaN               NaN              NaN
# 3 2015-02-04               NaN               NaN              NaN
# 4 2015-02-05               NaN               NaN              NaN
#
#    MultidayPrecipTotal  PeakGustTime  Precipitation  Snowfall  MinSoilTemp  \
# 0                  NaN           NaN           0.03       NaN          NaN
# 1                  NaN           NaN           0.04       NaN          NaN
# 2                  NaN           NaN           0.00       NaN          NaN
# 3                  NaN           NaN           0.50       NaN          NaN
# 4                  NaN           NaN           0.59       NaN          NaN
#
#    TimeAvgTemp  TimeMaxTemp  TimeMinTemp  TempAtObs  2MinMaxWindDirection  \
# 0          NaN          NaN          NaN        NaN                   NaN
# 1          NaN          NaN          NaN        NaN                   NaN
# 2          NaN          NaN          NaN        NaN                   NaN
# 3          NaN          NaN          NaN        NaN                   NaN
# 4          NaN          NaN          NaN        NaN                   NaN
#
#    5MinMaxWindDirection  2MinMaxWindSpeed  5MinMaxWindSpeed    Fog  Heavy Fog  \
# 0                   NaN               NaN               NaN  False      False
# 1                   NaN               NaN               NaN  False      False
# 2                   NaN               NaN               NaN  False      False
# 3                   NaN               NaN               NaN  False      False
# 4                   NaN               NaN               NaN  False      False
#
#    Thunder  Ice Pellets   Hail   Rime  Smoke  Tornado  High Wind   Mist  \
# 0    False        False  False  False  False    False      False  False
# 1    False        False  False  False  False    False      False  False
# 2    False        False  False  False  False    False      False  False
# 3    False        False  False  False  False    False      False  False
# 4    False        False  False  False  False    False      False  False
#
#    Drizzle   Rain   Snow  Ground Fog
# 0    False  False  False       False
# 1    False  False  False       False
# 2    False  False  False       False
# 3    False  False  False       False
# 4    False  False  False       False

# %%
decapitalize = {"STATION":"Station", "NAME":"Name", "LATITUDE":"Latitude", "LONGITUDE":"Longitude", "ELEVATION":"Elevation", "DATE":"Date"}

weather.rename(columns = decapitalize, inplace = True)

# %%
weather.set_index(["Date", "Station"], inplace = True)

# %%
weather.sort_index(ascending = False)
# Out:
#                                                         Name  Latitude  \
# Date       Station
# 2023-09-29 USW00012930            NEW ORLEANS AUDUBON, LA US  29.91660
#            USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755
#            US1LAOR0014            NEW ORLEANS 3.8 WSW, LA US  29.93772
#            US1LAOR0009              NEW ORLEANS 5.0 N, LA US  30.01515
# 2023-09-28 USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934
# ...                                                      ...       ...
# 2011-01-02 USC00166666            NEW ORLEANS ALGIERS, LA US  29.95080
# 2011-01-01 USW00053917  NEW ORLEANS LAKEFRONT AIRPORT, LA US  30.04934
#            USW00012930            NEW ORLEANS AUDUBON, LA US  29.91660
#            USW00012916            NEW ORLEANS AIRPORT, LA US  29.99755
#            USC00166666            NEW ORLEANS ALGIERS, LA US  29.95080
#
#                         Longitude  Elevation  AverageDailyWind  \
# Date       Station
# 2023-09-29 USW00012930 -90.130200        6.1               NaN
#            USW00012916 -90.277720       -1.0               NaN
#            US1LAOR0014 -90.131310        2.1               NaN
#            US1LAOR0009 -90.065586        0.6               NaN
# 2023-09-28 USW00053917 -90.028990        0.9             15.43
# ...                           ...        ...               ...
# 2011-01-02 USC00166666 -90.051100        0.6               NaN
# 2011-01-01 USW00053917 -90.028990        0.9               NaN
#            USW00012930 -90.130200        6.1               NaN
#            USW00012916 -90.277720       -1.0             12.75
#            USC00166666 -90.051100        0.6               NaN
#
#                         NumDaysPrecipAvg  FastestWindTime  \
# Date       Station
# 2023-09-29 USW00012930               NaN              NaN
#            USW00012916               NaN              NaN
#            US1LAOR0014               NaN              NaN
#            US1LAOR0009               NaN              NaN
# 2023-09-28 USW00053917               NaN              NaN
# ...                                  ...              ...
# 2011-01-02 USC00166666               NaN              NaN
# 2011-01-01 USW00053917               NaN              NaN
#            USW00012930               NaN              NaN
#            USW00012916               NaN           1013.0
#            USC00166666               NaN              NaN
#
#                         MultidayPrecipTotal  PeakGustTime  Precipitation  \
# Date       Station
# 2023-09-29 USW00012930                  NaN           NaN           0.00
#            USW00012916                  NaN           NaN            NaN
#            US1LAOR0014                  NaN           NaN           0.00
#            US1LAOR0009                  NaN           NaN           0.00
# 2023-09-28 USW00053917                  NaN        1815.0           0.00
# ...                                     ...           ...            ...
# 2011-01-02 USC00166666                  NaN           NaN           0.00
# 2011-01-01 USW00053917                  NaN           NaN           0.16
#            USW00012930                  NaN           NaN           0.04
#            USW00012916                  NaN        1003.0           0.18
#            USC00166666                  NaN           NaN           0.10
#
#                         Snowfall  MinSoilTemp  TimeAvgTemp  TimeMaxTemp  \
# Date       Station
# 2023-09-29 USW00012930       NaN          NaN          NaN         85.0
#            USW00012916       NaN          NaN         78.0          NaN
#            US1LAOR0014       0.0          NaN          NaN          NaN
#            US1LAOR0009       0.0          NaN          NaN          NaN
# 2023-09-28 USW00053917       NaN          NaN          NaN         87.0
# ...                          ...          ...          ...          ...
# 2011-01-02 USC00166666       NaN          NaN          NaN          NaN
# 2011-01-01 USW00053917       NaN          NaN          NaN         72.0
#            USW00012930       NaN          NaN          NaN         70.0
#            USW00012916       NaN          NaN          NaN         73.0
#            USC00166666       NaN          NaN          NaN          NaN
#
#                         TimeMinTemp  TempAtObs  2MinMaxWindDirection  \
# Date       Station
# 2023-09-29 USW00012930         73.0       73.0                   NaN
#            USW00012916          NaN        NaN                   NaN
#            US1LAOR0014          NaN        NaN                   NaN
#            US1LAOR0009          NaN        NaN                   NaN
# 2023-09-28 USW00053917         77.0        NaN                  60.0
# ...                             ...        ...                   ...
# 2011-01-02 USC00166666          NaN        NaN                   NaN
# 2011-01-01 USW00053917         50.0       52.0                   NaN
#            USW00012930         51.0       51.0                   NaN
#            USW00012916         50.0        NaN                 340.0
#            USC00166666          NaN        NaN                   NaN
#
#                         5MinMaxWindDirection  2MinMaxWindSpeed  \
# Date       Station
# 2023-09-29 USW00012930                   NaN               NaN
#            USW00012916                   NaN               NaN
#            US1LAOR0014                   NaN               NaN
#            US1LAOR0009                   NaN               NaN
# 2023-09-28 USW00053917                  90.0              21.9
# ...                                      ...               ...
# 2011-01-02 USC00166666                   NaN               NaN
# 2011-01-01 USW00053917                   NaN               NaN
#            USW00012930                   NaN               NaN
#            USW00012916                 320.0              21.0
#            USC00166666                   NaN               NaN
#
#                         5MinMaxWindSpeed    Fog  Heavy Fog  Thunder  \
# Date       Station
# 2023-09-29 USW00012930               NaN  False      False    False
#            USW00012916               NaN  False      False    False
#            US1LAOR0014               NaN  False      False    False
#            US1LAOR0009               NaN  False      False    False
# 2023-09-28 USW00053917              25.9  False      False    False
# ...                                  ...    ...        ...      ...
# 2011-01-02 USC00166666               NaN  False      False    False
# 2011-01-01 USW00053917               NaN  False      False    False
#            USW00012930               NaN  False      False    False
#            USW00012916              30.0   True      False    False
#            USC00166666               NaN  False      False    False
#
#                         Ice Pellets   Hail   Rime  Smoke  Tornado  High Wind  \
# Date       Station
# 2023-09-29 USW00012930        False  False  False  False    False      False
#            USW00012916        False  False  False  False    False      False
#            US1LAOR0014        False  False  False  False    False      False
#            US1LAOR0009        False  False  False  False    False      False
# 2023-09-28 USW00053917        False  False  False  False    False      False
# ...                             ...    ...    ...    ...      ...        ...
# 2011-01-02 USC00166666        False  False  False  False    False      False
# 2011-01-01 USW00053917        False  False  False  False    False      False
#            USW00012930        False  False  False  False    False      False
#            USW00012916        False  False  False  False    False      False
#            USC00166666        False  False  False  False    False      False
#
#                          Mist  Drizzle   Rain   Snow  Ground Fog
# Date       Station
# 2023-09-29 USW00012930  False    False  False  False       False
#            USW00012916  False    False  False  False       False
#            US1LAOR0014  False    False  False  False       False
#            US1LAOR0009  False    False  False  False       False
# 2023-09-28 USW00053917  False    False  False  False       False
# ...                       ...      ...    ...    ...         ...
# 2011-01-02 USC00166666  False    False  False  False       False
# 2011-01-01 USW00053917  False    False  False  False       False
#            USW00012930  False    False  False  False       False
#            USW00012916   True     True   True  False       False
#            USC00166666  False    False  False  False       False
#
# [23479 rows x 34 columns]
